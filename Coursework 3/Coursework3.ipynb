# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sms

year = ['2015','2016','2017','2018','2019']
Car_rate = [1462,1451,1510,1438,1392 ]
Eng_rate = [1820,1765,1620,1519,1437 ]
plt.figure(figsize = (12, 8))

plt.plot(year, Eng_rate,'r', linewidth = 3,color ='deepskyblue' ,label= 'London')
plt.plot(year, Car_rate, 'r', linewidth = 3, color ='red', label ='England')


plt.plot(year, Car_rate, 'or',markersize = 6, color ='red')
plt.plot(year, Eng_rate, 'or',markersize = 6, color ='deepskyblue')


plt.tick_params(labelsize=15)
plt.ylabel("Car casualty rate per million population", fontsize=22)
plt.xlabel("Year", fontsize=22) 
plt.title("Car casualty rates of Greater London and England from 2015 to 2019", fontsize=23, y=1.06)
plt.xticks(rotation=360, fontsize=15)
plt.ylim(1350, 1900)

plt.legend(fontsize=15)
plt.savefig('Figure3.png')
plt.show()

# %%
year = ['2015','2016','2017','2018','2019']
Motor_rate = [628,598,631,575,604 ]
Eng2_rate = [337,324,303,279,268 ]
plt.figure(figsize = (12, 8))

plt.plot(year, Eng2_rate,'r', linewidth = 3,color ='deepskyblue' ,label= 'London')
plt.plot(year, Motor_rate, 'r', linewidth = 3, color ='red', label ='England')


plt.plot(year, Motor_rate, 'or',markersize = 6, color ='red')
plt.plot(year, Eng2_rate, 'or',markersize = 6, color ='deepskyblue')


plt.tick_params(labelsize=15)
plt.ylabel("Motorcyclist casualty rate per million population", fontsize=18)
plt.xlabel("Year", fontsize=22) 
plt.title("Motorcyclist casualty rates of Greater London and England from 2015 to 2019", fontsize=21, y=1.06)
plt.xticks(rotation=360, fontsize=15)
plt.ylim(200, 800)

plt.legend(fontsize=15)
plt.savefig('Figure4.png')
plt.show()

# %%
data2 = pd.read_csv('data2.csv')
plt.figure(figsize = (12, 8))


x, y= data2[['Year']], data2[['Car casualty rate']]
plt.plot(x, y,linestyle='', marker='o');

plt.xlim(2014, 2020)
plt.xticks(size=16)  
plt.yticks(size=16)
plt.ylabel("Car casualty rate per million population", fontsize=22) 
plt.title("Car casualty rates of Greater London from 2015 to 2019", fontsize=24, y=1.06,x =0.45)
plt.xlabel("Year", fontsize=22) 
plt.savefig('Figure2.png')
plt.show()

# %%
data4 = pd.read_csv('data4.csv')
plt.figure(figsize = (12, 8))


x, y= data4[['Year']], data4[['Motorcyclist casualty rate']]
plt.plot(x, y,linestyle='', marker='o');


plt.xlim(2014, 2020)
plt.xticks(size=16)  
plt.yticks(size=16)
plt.ylabel("Motorcyclist casualty rate per million population", fontsize=18) 
plt.title("Motorcyclist casualty rates of Greater London from 2015 to 2019", fontsize=23, y=1.06,x =0.45)
plt.xlabel("Year", fontsize=22) 
plt.savefig('Figure5.png')
plt.show()

# %%
data = pd.read_csv('data.csv')
from sklearn.preprocessing import LabelEncoder as LE
# The next lines import the necessary packages to perform the regression:



#data = np.genfromtxt(data_filename,delimiter = ',')




y_values = data[['Car casualty rate']]
explained_variable = ['Population per square kilometre', 'Total major road dual carriageway', 'Road density', 
                      'Traffic Flows - Cars','Traffic Flows - All vehicles', 'Cars', 'Motor cycles', 'Light goods', 
                      'Heavy goods','Buses and coaches']
x_values = data[explained_variable]

# These lines perform the regression procedure:
X_values = sms.add_constant(x_values)
regression_model_a = sms.OLS(y_values, X_values)
regression_model_b = regression_model_a.fit()
# and print a summary of the results:
print(regression_model_b.summary())
print() # blank line

# Now we store all the relevant values:
predictor_coeffs  = regression_model_b.params[1:]
constant          = regression_model_b.params[0] # called the 'intercept' in simple regression
Rsquared          = regression_model_b.rsquared
MSE               = regression_model_b.mse_resid
pvalues_T         = regression_model_b.pvalues[1:]
pvalue_F          = regression_model_b.f_pvalue

# Note that predictor_coeffs is a list of the best-fit coefficients for x1, x2, x3, ...
# Similarly, pvalues_T is a list of the p-values associated with each of these variables in turn.

# Print these summary stats:
print("predictor coefficients =", predictor_coeffs)
print("constant               =", constant)
print("Rsquared               =", Rsquared)
print("MSE                    =", MSE)
print("T-test pvalues         =", pvalues_T)
print("F-test pvalue          =", pvalue_F)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:      Car casualty rate   R-squared:                       0.623
# Model:                            OLS   Adj. R-squared:                  0.598
# Method:                 Least Squares   F-statistic:                     24.61
# Date:                Mon, 18 Jan 2021   Prob (F-statistic):           6.34e-27
# Time:                        11:51:30   Log-Likelihood:                -1111.9
# No. Observations:                 160   AIC:                             2246.
# Df Residuals:                     149   BIC:                             2280.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# ...

# %%
data3 = pd.read_csv('data3.csv')
from sklearn.preprocessing import LabelEncoder as LE
# The next lines import the necessary packages to perform the regression:



#data = np.genfromtxt(data_filename,delimiter = ',')




y_values = data3[['Motorcyclist casualty rate']]
explained_variable = ['Population per square kilometre', 'Total major road dual carriageway', 'Road density', 
                      'Traffic Flows - Cars','Traffic Flows - All vehicles', 'Cars', 'Motor cycles', 'Light goods', 
                      'Heavy goods','Buses and coaches']
x_values = data3[explained_variable]

# These lines perform the regression procedure:
X_values = sms.add_constant(x_values)
regression_model_a = sms.OLS(y_values, X_values)
regression_model_b = regression_model_a.fit()
# and print a summary of the results:
print(regression_model_b.summary())
print() # blank line

# Now we store all the relevant values:
predictor_coeffs  = regression_model_b.params[1:]
constant          = regression_model_b.params[0] # called the 'intercept' in simple regression
Rsquared          = regression_model_b.rsquared
MSE               = regression_model_b.mse_resid
pvalues_T         = regression_model_b.pvalues[1:]
pvalue_F          = regression_model_b.f_pvalue

# Note that predictor_coeffs is a list of the best-fit coefficients for x1, x2, x3, ...
# Similarly, pvalues_T is a list of the p-values associated with each of these variables in turn.

# Print these summary stats:
print("predictor coefficients =", predictor_coeffs)
print("constant               =", constant)
print("Rsquared               =", Rsquared)
print("MSE                    =", MSE)
print("T-test pvalues         =", pvalues_T)
print("F-test pvalue          =", pvalue_F)
# Out:
#                                 OLS Regression Results
# ...
# Dep. Variable:     Motorcyclist casualty rate   R-squared:                       0.756
# Model:                                    OLS   Adj. R-squared:                  0.739
# Method:                         Least Squares   F-statistic:                     46.13
# Date:                        Mon, 18 Jan 2021   Prob (F-statistic):           1.16e-40
# Time:                                11:51:44   Log-Likelihood:                -1041.5
# No. Observations:                         160   AIC:                             2105.
# Df Residuals:                             149   BIC:                             2139.
# Df Model:                                  10
# Covariance Type:                    nonrobust
# ...
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# ...
